# %%
import os
import tensorflow as tf

# If there are multiple GPUs and we only want to use one/some, set the number in the visible device list.
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"]="0"

# This sets the GPU to allocate memory only as needed
physical_devices = tf.config.experimental.list_physical_devices('GPU')
if len(physical_devices) != 0:
    tf.config.experimental.set_memory_growth(physical_devices[0], True)

# %% [markdown]
# ### **1. Loading the dataset**
# This assignment will focus on the CIFAR10 dataset. This is a collection of small images in 10 classes such as cars, cats, birds, etc. You can find more information here: https://www.cs.toronto.edu/~kriz/cifar.html. We start by loading and examining the data.

# %%
import numpy as np
from tensorflow.keras.datasets import cifar10

(X_train, y_train), (X_test, y_test) = cifar10.load_data()

print("Shape of training data:")
print(X_train.shape)
print(y_train.shape)
print("Shape of test data:")
print(X_test.shape)
print(y_test.shape)
# Out:
# Shape of training data:
# (50000, 32, 32, 3)
# (50000, 1)
# Shape of test data:
# (10000, 32, 32, 3)
# (10000, 1)

# %% [markdown]
# #### **<span style="color:red">Question 1:</span>**
# The shape of X_train and X_test has 4 values. What do each of these represent?

# %% [markdown]
# ##### **Plotting some images**
# This plots a random selection of images from each class. Rerun the cell to see a different selection.

# %%
from Custom import PlotRandomFromEachClass

cifar_labels = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
PlotRandomFromEachClass(X_train, y_train, 3, labels=cifar_labels)

# %% [markdown]
# ##### **Preparing the dataset**
# Just like the MNIST dataset we normalize the images to [0,1] and transform the class indices to one-hot encoded vectors.

# %%
from tensorflow.keras.utils import to_categorical

# Transform label indices to one-hot encoded vectors
y_train_c = to_categorical(y_train, num_classes=10)
y_test_c  = to_categorical(y_test , num_classes=10)

# Normalization of pixel values (to [0-1] range)
X_train = X_train.astype('float32') / 255
X_test  = X_test.astype('float32')  / 255

# %% [markdown]
# ### **2. Fully connected classifier**
# We will start by creating a fully connected classifier using the ```Dense``` layer. We give you the first layer that flattens the image features to a single vector. Add the remaining layers to the network.
#
# Consider what the size of the output must be and what activation function you should use in the output layer.

# %%
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, Flatten

x_in = Input(shape=X_train.shape[1:])
x = Flatten()(x_in)

# === Add your code here ===
x = Dense(200, activation='relu')(x)
x = Dense(64, activation='relu')(x)
x = Dense(10, activation='softmax')(x)
# ==========================

model = Model(inputs=x_in, outputs=x)

# Now we build the model using Stochastic Gradient Descent with Nesterov momentum. We use accuracy as the metric.
sgd = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(optimizer=sgd, loss='categorical_crossentropy', metrics=['accuracy'])
model.summary(100)
# Out:
# Model: "functional_1"
# ____________________________________________________________________________________________________
# Layer (type)                                 Output Shape                            Param #
# ====================================================================================================
# input_1 (InputLayer)                         [(None, 32, 32, 3)]                     0
# ____________________________________________________________________________________________________
# flatten (Flatten)                            (None, 3072)                            0
# ____________________________________________________________________________________________________
# dense (Dense)                                (None, 200)                             614600
# ____________________________________________________________________________________________________
# dense_1 (Dense)                              (None, 64)                              12864
# ____________________________________________________________________________________________________
# dense_2 (Dense)                              (None, 10)                              650
# ====================================================================================================
# Total params: 628,114
# Trainable params: 628,114
# Non-trainable params: 0
# ____________________________________________________________________________________________________

# %% [markdown]
# ##### **Training the model**
# In order to show the differences between models in the first parts of the assignment, we will restrict the training to the following command using 15 epochs, batch size 32, and 20% validation data. From section 5 and forward you can change this as you please to increase the accuracy, but for now stick with this command.

# %%
history = model.fit(X_train,y_train_c, epochs=15, batch_size=32, verbose=1, validation_split=0.2)
# Out:
# Epoch 1/15
# 1250/1250 [==============================] - 13s 11ms/step - loss: 1.8419 - accuracy: 0.3325 - val_loss: 1.7625 - val_accuracy: 0.3617
# Epoch 2/15
# 1250/1250 [==============================] - 9s 7ms/step - loss: 1.6896 - accuracy: 0.3925 - val_loss: 1.6498 - val_accuracy: 0.4118
# Epoch 3/15
# 1250/1250 [==============================] - 9s 7ms/step - loss: 1.6183 - accuracy: 0.4188 - val_loss: 1.6792 - val_accuracy: 0.4023
# Epoch 4/15
# 1250/1250 [==============================] - 9s 7ms/step - loss: 1.5791 - accuracy: 0.4360 - val_loss: 1.6344 - val_accuracy: 0.4094
# Epoch 5/15
# 1250/1250 [==============================] - 9s 7ms/step - loss: 1.5419 - accuracy: 0.4464 - val_loss: 1.6282 - val_accuracy: 0.4222
# Epoch 6/15
# 1250/1250 [==============================] - 10s 8ms/step - loss: 1.5166 - accuracy: 0.4561 - val_loss: 1.5700 - val_accuracy: 0.4358
# Epoch 7/15
# 1250/1250 [==============================] - 10s 8ms/step - loss: 1.4933 - accuracy: 0.4644 - val_loss: 1.5696 - val_accuracy: 0.4459
# Epoch 8/15
# 1250/1250 [==============================] - 9s 7ms/step - loss: 1.4756 - accuracy: 0.4701 - val_loss: 1.5398 - val_accuracy: 0.4463
# Epoch 9/15
# 1250/1250 [==============================] - 9s 7ms/step - loss: 1.4587 - accuracy: 0.4736 - val_loss: 1.5469 - val_accuracy: 0.4499
# Epoch 10/15
# 1250/1250 [==============================] - 11s 9ms/step - loss: 1.4418 - accuracy: 0.4826 - val_loss: 1.5048 - val_accuracy: 0.4712
# Epoch 11/15
# 1250/1250 [==============================] - 9s 7ms/step - loss: 1.4263 - accuracy: 0.4888 - val_loss: 1.5134 - val_accuracy: 0.4639
# Epoch 12/15
# 1250/1250 [==============================] - 9s 7ms/step - loss: 1.4116 - accuracy: 0.4940 - val_loss: 1.5666 - val_accuracy: 0.4562
# Epoch 13/15
# 1250/1250 [==============================] - 10s 8ms/step - loss: 1.4049 - accuracy: 0.4948 - val_loss: 1.5263 - val_accuracy: 0.4654
# Epoch 14/15
# 1250/1250 [==============================] - 9s 7ms/step - loss: 1.3866 - accuracy: 0.5037 - val_loss: 1.5193 - val_accuracy: 0.4652
# Epoch 15/15
# 1250/1250 [==============================] - 11s 8ms/step - loss: 1.3778 - accuracy: 0.5047 - val_loss: 1.5791 - val_accuracy: 0.4434

# %% [markdown]
# ##### **Evaluating the model**
# We use ```model.evaluate``` to get the loss and metric scores on the test data. To plot the results we give you a custom function that does the work for you.

# %%
score = model.evaluate(X_test, y_test_c, batch_size=128, verbose=0)

for i in range(len(score)):
    print("Test " + model.metrics_names[i] + " = %.3f" % score[i])
# Out:
# Test loss = 1.570
# Test accuracy = 0.450

# %%
from Custom import PlotModelEval

# Custom function for evaluating the model and plotting training history
PlotModelEval(model, history, X_test, y_test, cifar_labels)

# %% [markdown]
# #### **<span style="color:red">Question 2:</span>**
# Train a model that achieves above 45% accuracy on the test data. In the report, provide a (short) description of your model and show the evaluation image.

# %% [markdown]
# #### **<span style="color:red">Question 3:</span>**
# Compare this model to the one you used for the MNIST dataset in the first assignment, in terms of size and test accuracy. Why do you think this dataset is much harder to classify than the MNIST handwritten digits?

# %% [markdown]
# ### **3. CNN classifier**
# We will now move on to a network architecture that is more suited for this problem, the convolutional neural network. The new layers you will use are ```Conv2D``` and ```MaxPooling2D```, which you can find the documentation of here https://www.tensorflow.org/api_docs/python/tf/keras/layers/Conv2D and here https://www.tensorflow.org/api_docs/python/tf/keras/layers/MaxPool2D.

# %% [markdown]
# ##### **Creating the CNN model**
#
# A common way to build convolutional neural networks is to create blocks of layers of the form **[convolution - activation - pooling]**, and then stack several of these block to create the full convolution stack. This is often followed by a fully connected network to create the output classes. Use this recipe to build a CNN that acheives at least 62% accuracy on the test data.
#
# *Side note. Although this is a common way to build CNNs, it is be no means the only or even best way. It is a good starting point, but later in part 5 you might want to explore other architectures to acheive even better performance.*

# %%
from tensorflow.keras.layers import Conv2D, MaxPooling2D

x_in = Input(shape=X_train.shape[1:])

# === Add your code here ===
x = Conv2D(32, 3, activation='relu')(x_in)
x = MaxPooling2D(pool_size=(2, 2))(x)
x = Conv2D(64, 3, activation='relu')(x)
x = MaxPooling2D(pool_size=(2, 2))(x)
x = Flatten()(x)
x = Dense(10, activation='softmax')(x)
# ==========================

model = Model(inputs=x_in, outputs=x)

sgd = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(loss='categorical_crossentropy', metrics=['accuracy'], optimizer=sgd)
model.summary(100)
# Out:
# Model: "functional_3"
# ____________________________________________________________________________________________________
# Layer (type)                                 Output Shape                            Param #
# ====================================================================================================
# input_2 (InputLayer)                         [(None, 32, 32, 3)]                     0
# ____________________________________________________________________________________________________
# conv2d (Conv2D)                              (None, 30, 30, 32)                      896
# ____________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)                 (None, 15, 15, 32)                      0
# ____________________________________________________________________________________________________
# conv2d_1 (Conv2D)                            (None, 13, 13, 64)                      18496
# ____________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)               (None, 6, 6, 64)                        0
# ____________________________________________________________________________________________________
# flatten_1 (Flatten)                          (None, 2304)                            0
# ____________________________________________________________________________________________________
# dense_3 (Dense)                              (None, 10)                              23050
# ====================================================================================================
# Total params: 42,442
# Trainable params: 42,442
# Non-trainable params: 0
# ____________________________________________________________________________________________________

# %% [markdown]
# ##### **Training the CNN**

# %%
history = model.fit(X_train, y_train_c, batch_size=32, epochs=15, verbose=1, validation_split=0.2)
# Out:
# Epoch 1/15
# 1250/1250 [==============================] - 58s 47ms/step - loss: 1.5914 - accuracy: 0.4308 - val_loss: 1.2918 - val_accuracy: 0.5395
# Epoch 2/15
# 1250/1250 [==============================] - 66s 53ms/step - loss: 1.1851 - accuracy: 0.5846 - val_loss: 1.1418 - val_accuracy: 0.6033
# Epoch 3/15
# 1250/1250 [==============================] - 63s 50ms/step - loss: 1.0511 - accuracy: 0.6358 - val_loss: 1.0705 - val_accuracy: 0.6307
# Epoch 4/15
# 1250/1250 [==============================] - 52s 42ms/step - loss: 0.9758 - accuracy: 0.6631 - val_loss: 1.1101 - val_accuracy: 0.6216
# Epoch 5/15
# 1250/1250 [==============================] - 71s 57ms/step - loss: 0.9117 - accuracy: 0.6864 - val_loss: 1.0522 - val_accuracy: 0.6391
# Epoch 6/15
# 1250/1250 [==============================] - 68s 55ms/step - loss: 0.8691 - accuracy: 0.6990 - val_loss: 1.0360 - val_accuracy: 0.6543
# Epoch 7/15
# 1250/1250 [==============================] - 63s 51ms/step - loss: 0.8221 - accuracy: 0.7145 - val_loss: 1.0036 - val_accuracy: 0.6600
# Epoch 8/15
# 1250/1250 [==============================] - 60s 48ms/step - loss: 0.7863 - accuracy: 0.7290 - val_loss: 1.0391 - val_accuracy: 0.6594
# Epoch 9/15
# 1250/1250 [==============================] - 60s 48ms/step - loss: 0.7601 - accuracy: 0.7372 - val_loss: 1.0703 - val_accuracy: 0.6566
# Epoch 10/15
# 1250/1250 [==============================] - 60s 48ms/step - loss: 0.7342 - accuracy: 0.7457 - val_loss: 1.0119 - val_accuracy: 0.6675
# Epoch 11/15
# 1250/1250 [==============================] - 55s 44ms/step - loss: 0.7085 - accuracy: 0.7540 - val_loss: 1.0525 - val_accuracy: 0.6600
# Epoch 12/15
# 1250/1250 [==============================] - 63s 50ms/step - loss: 0.6900 - accuracy: 0.7601 - val_loss: 1.0760 - val_accuracy: 0.6714
# Epoch 13/15
# 1250/1250 [==============================] - 56s 45ms/step - loss: 0.6731 - accuracy: 0.7641 - val_loss: 1.0691 - val_accuracy: 0.6612
# Epoch 14/15
# 1250/1250 [==============================] - 56s 45ms/step - loss: 0.6544 - accuracy: 0.7727 - val_loss: 1.1032 - val_accuracy: 0.6613
# Epoch 15/15
# 1250/1250 [==============================] - 56s 45ms/step - loss: 0.6413 - accuracy: 0.7780 - val_loss: 1.0923 - val_accuracy: 0.6651

# %% [markdown]
# ##### **Evaluating the CNN**

# %%
score = model.evaluate(X_test, y_test_c, batch_size=128, verbose=0)

for i in range(len(score)):
    print("Test " + model.metrics_names[i] + " = %.3f" % score[i])
# Out:
# Test loss = 1.111
# Test accuracy = 0.661

# %%
PlotModelEval(model, history, X_test, y_test, cifar_labels)

# %% [markdown]
# #### **<span style="color:red">Question 4:</span>**
# Train a model that achieves at least 62% test accuracy. In the report, provide a (short) description of your model and show the evaluation image.

# %% [markdown]
# #### **<span style="color:red">Question 5:</span>**
# Compare this model with the previous fully connected model. You should find that this one is much more efficient, i.e. achieves higher accuracy with fewer parameters. Explain in your own words how this is possible.

# %% [markdown]
# ### **4. Regularization**

# %% [markdown]
# #### **4.1 Dropout**
# You have probably seen that your CNN model overfits the training data. One way to prevent this is to add ```Dropout``` layers to the model, that randomly "drops" hidden nodes each training-iteration by setting their output to zero. Thus the model cannot rely on a small set of very good hidden features, but must instead learns to use different sets of hidden features each time. Dropout layers are usually added after the pooling layers in the convolution part of the model, or after activations in the fully connected part of the model.
#
# *Side note. In the next assignment you will work with Ensemble models, a way to use the output from several individual models to achieve higher performance than each model can achieve on its own. One way to interpret Dropout is that each random selection of nodes is a separate model that is trained only on the current iteration. The final output is then the average of outputs from all the individual models. In other words, Dropout can be seen as a way to build ensembling directly into the network, without having to train several models explicitly.*
#
# Extend your previous model with the Dropout layer and test the new performance.

# %%
from tensorflow.keras.layers import Dropout

x_in = Input(shape=X_train.shape[1:])

# === Add your code here ===
x_in = Input(shape=X_train.shape[1:])
# === Add your code here ===
x = Conv2D(32, 3, activation='relu')(x_in)
x = MaxPooling2D(pool_size=(2, 2))(x)
x = Dropout(0.2)(x)
x = Conv2D(64, 3, activation='relu')(x)
x = MaxPooling2D(pool_size=(2, 2))(x)
x = Dropout(0.2)(x)
x = Flatten()(x)
x = Dense(10, activation='softmax')(x)
# ==========================

model = Model(inputs=x_in, outputs=x)

# Compile model
sgd = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(loss='categorical_crossentropy', metrics=['accuracy'], optimizer=sgd)
model.summary(100)
# Out:
# Model: "functional_5"
# ____________________________________________________________________________________________________
# Layer (type)                                 Output Shape                            Param #
# ====================================================================================================
# input_4 (InputLayer)                         [(None, 32, 32, 3)]                     0
# ____________________________________________________________________________________________________
# conv2d_2 (Conv2D)                            (None, 30, 30, 32)                      896
# ____________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)               (None, 15, 15, 32)                      0
# ____________________________________________________________________________________________________
# dropout (Dropout)                            (None, 15, 15, 32)                      0
# ____________________________________________________________________________________________________
# conv2d_3 (Conv2D)                            (None, 13, 13, 64)                      18496
# ____________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)               (None, 6, 6, 64)                        0
# ____________________________________________________________________________________________________
# dropout_1 (Dropout)                          (None, 6, 6, 64)                        0
# ____________________________________________________________________________________________________
# flatten_2 (Flatten)                          (None, 2304)                            0
# ____________________________________________________________________________________________________
# dense_4 (Dense)                              (None, 10)                              23050
# ====================================================================================================
# Total params: 42,442
# Trainable params: 42,442
# Non-trainable params: 0
# ____________________________________________________________________________________________________

# %%
history = model.fit(X_train, y_train_c, batch_size=32, epochs=15, verbose=1, validation_split=0.2)
# Out:
# Epoch 1/15
# 1250/1250 [==============================] - 68s 54ms/step - loss: 1.6636 - accuracy: 0.3985 - val_loss: 1.3688 - val_accuracy: 0.5113
# Epoch 2/15
# 1250/1250 [==============================] - 62s 49ms/step - loss: 1.3172 - accuracy: 0.5342 - val_loss: 1.2401 - val_accuracy: 0.5658
# Epoch 3/15
# 1250/1250 [==============================] - 64s 51ms/step - loss: 1.1993 - accuracy: 0.5798 - val_loss: 1.1495 - val_accuracy: 0.6000
# Epoch 4/15
# 1250/1250 [==============================] - 66s 53ms/step - loss: 1.1279 - accuracy: 0.6020 - val_loss: 1.0708 - val_accuracy: 0.6294
# Epoch 5/15
# 1250/1250 [==============================] - 87s 70ms/step - loss: 1.0734 - accuracy: 0.6260 - val_loss: 1.0335 - val_accuracy: 0.6474
# Epoch 6/15
# 1250/1250 [==============================] - 78s 63ms/step - loss: 1.0317 - accuracy: 0.6386 - val_loss: 1.0465 - val_accuracy: 0.6318
# Epoch 7/15
# 1250/1250 [==============================] - 66s 53ms/step - loss: 0.9889 - accuracy: 0.6561 - val_loss: 0.9763 - val_accuracy: 0.6666
# Epoch 8/15
# 1250/1250 [==============================] - 64s 51ms/step - loss: 0.9674 - accuracy: 0.6653 - val_loss: 1.0366 - val_accuracy: 0.6516
# Epoch 9/15
# 1250/1250 [==============================] - 62s 49ms/step - loss: 0.9450 - accuracy: 0.6709 - val_loss: 0.9641 - val_accuracy: 0.6730
# Epoch 10/15
# 1250/1250 [==============================] - 63s 50ms/step - loss: 0.9238 - accuracy: 0.6827 - val_loss: 0.9351 - val_accuracy: 0.6806
# Epoch 11/15
# 1250/1250 [==============================] - 66s 53ms/step - loss: 0.9057 - accuracy: 0.6867 - val_loss: 0.9143 - val_accuracy: 0.6876
# Epoch 12/15
# 1250/1250 [==============================] - 66s 52ms/step - loss: 0.8977 - accuracy: 0.6890 - val_loss: 0.9345 - val_accuracy: 0.6817
# Epoch 13/15
# 1250/1250 [==============================] - 61s 49ms/step - loss: 0.8805 - accuracy: 0.6951 - val_loss: 0.9296 - val_accuracy: 0.6794
# Epoch 14/15
# 1250/1250 [==============================] - 60s 48ms/step - loss: 0.8716 - accuracy: 0.6973 - val_loss: 0.9453 - val_accuracy: 0.6695
# Epoch 15/15
# 1250/1250 [==============================] - 60s 48ms/step - loss: 0.8661 - accuracy: 0.6979 - val_loss: 0.9217 - val_accuracy: 0.6782

# %%
score = model.evaluate(X_test, y_test_c, batch_size=128, verbose=0)

for i in range(len(score)):
    print("Test " + model.metrics_names[i] + " = %.3f" % score[i])
# Out:
# Test loss = 0.943
# Test accuracy = 0.674

# %%
PlotModelEval(model, history, X_test, y_test, cifar_labels)

# %% [markdown]
# #### **<span style="color:red">Question 6:</span>**
# Train the modified CNN-model. Save the evaluation image for the report.

# %% [markdown]
# #### **<span style="color:red">Question 7:</span>**
# Compare this model and the previous in terms of the training accuracy, validation accuracy, and test accuracy. Explain the similarities and differences (remember that the only difference between the models should be the addition of Dropout layers).
#
# Hint: what does the dropout layer do at test time?

# %% [markdown]
# #### **4.2 Batch normalization**
# The final layer we will explore is ```BatchNormalization```. As the name suggests, this layer normalizes the data in each batch to have a specific mean and standard deviation, which is learned during training. The reason for this is quite complicated (and still debated among the experts), but suffice to say that it helps the optimization converge faster which means we get higher performance in fewer epochs. The normalization is done separatly for each feature, i.e. the statistics are calculated accross the batch dimension of the input data. The equations for batch-normalizing one feature are the following, where $N$ is the batch size, $x$ the input features, and $y$ the normalized output features:
#
# $$ \mu = \frac{1}{N} \sum_{i=0}^{N}x_i,\;\;\;\; \sigma^2 = \frac{1}{N} \sum_{i=0}^{N}(x_i - \mu)^2 $$
#
# $$ \hat{x}_i = \frac{x_i - \mu}{\sqrt{\sigma^2 + \epsilon}} $$
#
# $$ y_i = \gamma \hat{x}_i + \beta $$
#
# At first glance this might look intimidating, but all it means is that we begin by scaling and shifting the data to have mean $\mu=0$ and standard deviation $\sigma=1$. After this we use the learnable parameters $\gamma$ and $\beta$ to decide the width and center of the final distribution. $\epsilon$ is a small constant value that prevents the denominator from being zero.
#
# In addition to learning the parameters $\gamma$ and $\beta$ by gradient decent just like the weights, Batch Normalization also keeps track of the running average of minibatch statistics $\mu$ and $\sigma$. These averages are used to normalize the test data. We can tune the rate at which the running averages are updated with the *momentum* parameter of the BatchNormalization layer. A large momentum means that the statistics converge more slowly and therefore requires more updates before it represents the data. A low momentum, on the other hand, adapts to the data more quickly but might lead to unstable behaviour if the latest minibatches are not representative of the whole dataset. For this test we recommend a momentum of 0.75, but you probably want to change this when you design a larger network in Section 5.
#
# The batch normalization layer should be added after the hidden layer linear transformation, but before the nonlinear activation. This means that we cannot specify the activation funciton in the ```Conv2D``` or ```Dense``` if we want to batch-normalize the output. We therefore need to use the ```Activation``` layer to add a separate activation to the network stack after batch normalization. For example, the convolution block will now look like **[conv - batchnorm - activation - pooling]**.
#
# Extend your previous model with batch normalization, both in the convolution and fully connected part of the model.

# %%
from tensorflow.keras.layers import BatchNormalization, Activation

x_in = Input(shape=X_train.shape[1:])

# === Add your code here ===
x_in = Input(shape=X_train.shape[1:])
# === Add your code here ===
x = Conv2D(32, 3)(x_in)
x = BatchNormalization(momentum =0.75)(x)
x = Activation('relu')(x)
x = MaxPooling2D(pool_size=(2, 2))(x)
x = Dropout(0.2)(x)
x = Conv2D(64, 3, padding ='same')(x)
x = BatchNormalization(momentum =0.75)(x)
x = Activation('relu')(x)
x = MaxPooling2D(pool_size=(2, 2))(x)
x = Dropout(0.2)(x)
x = Flatten()(x)
x = Dense(10, activation='softmax')(x)
# ==========================

model = Model(inputs=x_in, outputs=x)

sgd = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(loss='categorical_crossentropy', metrics=['accuracy'], optimizer=sgd)
model.summary(100)
# Out:
# Model: "functional_7"
# ____________________________________________________________________________________________________
# Layer (type)                                 Output Shape                            Param #
# ====================================================================================================
# input_6 (InputLayer)                         [(None, 32, 32, 3)]                     0
# ____________________________________________________________________________________________________
# conv2d_4 (Conv2D)                            (None, 30, 30, 32)                      896
# ____________________________________________________________________________________________________
# batch_normalization (BatchNormalization)     (None, 30, 30, 32)                      128
# ____________________________________________________________________________________________________
# activation (Activation)                      (None, 30, 30, 32)                      0
# ____________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)               (None, 15, 15, 32)                      0
# ____________________________________________________________________________________________________
# dropout_2 (Dropout)                          (None, 15, 15, 32)                      0
# ____________________________________________________________________________________________________
# conv2d_5 (Conv2D)                            (None, 15, 15, 64)                      18496
# ____________________________________________________________________________________________________
# batch_normalization_1 (BatchNormalization)   (None, 15, 15, 64)                      256
# ____________________________________________________________________________________________________
# activation_1 (Activation)                    (None, 15, 15, 64)                      0
# ____________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)               (None, 7, 7, 64)                        0
# ____________________________________________________________________________________________________
# dropout_3 (Dropout)                          (None, 7, 7, 64)                        0
# ____________________________________________________________________________________________________
# flatten_3 (Flatten)                          (None, 3136)                            0
# ____________________________________________________________________________________________________
# dense_5 (Dense)                              (None, 10)                              31370
# ====================================================================================================
# Total params: 51,146
# Trainable params: 50,954
# Non-trainable params: 192
# ____________________________________________________________________________________________________

# %%
history = model.fit(X_train, y_train_c, batch_size=32, epochs=50, verbose=1, validation_split=0.2)
# Out:
# Epoch 1/50
# 1250/1250 [==============================] - 153s 123ms/step - loss: 1.5082 - accuracy: 0.4855 - val_loss: 1.2316 - val_accuracy: 0.5686
# Epoch 2/50
# 1250/1250 [==============================] - 160s 128ms/step - loss: 1.1279 - accuracy: 0.6012 - val_loss: 1.0787 - val_accuracy: 0.6213
# Epoch 3/50
# 1250/1250 [==============================] - 142s 114ms/step - loss: 1.0194 - accuracy: 0.6464 - val_loss: 0.9949 - val_accuracy: 0.6589
# Epoch 4/50
# 1250/1250 [==============================] - 143s 114ms/step - loss: 0.9552 - accuracy: 0.6686 - val_loss: 0.9578 - val_accuracy: 0.6707
# Epoch 5/50
# 1250/1250 [==============================] - 149s 119ms/step - loss: 0.9084 - accuracy: 0.6863 - val_loss: 0.8867 - val_accuracy: 0.6957
# Epoch 6/50
# 1250/1250 [==============================] - 160s 128ms/step - loss: 0.8773 - accuracy: 0.6949 - val_loss: 0.8794 - val_accuracy: 0.7000
# Epoch 7/50
# 1250/1250 [==============================] - 143s 114ms/step - loss: 0.8497 - accuracy: 0.7063 - val_loss: 0.8966 - val_accuracy: 0.6900
# Epoch 8/50
# 1250/1250 [==============================] - 144s 115ms/step - loss: 0.8226 - accuracy: 0.7143 - val_loss: 0.8592 - val_accuracy: 0.7061 0.8226 - ac
# Epoch 9/50
# 1250/1250 [==============================] - 141s 113ms/step - loss: 0.8011 - accuracy: 0.7217 - val_loss: 0.8335 - val_accuracy: 0.7192
# Epoch 10/50
# 1250/1250 [==============================] - 150s 120ms/step - loss: 0.7885 - accuracy: 0.7283 - val_loss: 0.8358 - val_accuracy: 0.7171
# Epoch 11/50
# 1250/1250 [==============================] - 115s 92ms/step - loss: 0.7775 - accuracy: 0.7300 - val_loss: 0.8133 - val_accuracy: 0.7270
# Epoch 12/50
# 1250/1250 [==============================] - 129s 104ms/step - loss: 0.7578 - accuracy: 0.7366 - val_loss: 0.8268 - val_accuracy: 0.7201
# Epoch 13/50
# 1250/1250 [==============================] - 139s 111ms/step - loss: 0.7506 - accuracy: 0.7397 - val_loss: 0.8183 - val_accuracy: 0.7225
# Epoch 14/50
# 1250/1250 [==============================] - 140s 112ms/step - loss: 0.7358 - accuracy: 0.7442 - val_loss: 0.7990 - val_accuracy: 0.7263
# Epoch 15/50
# 1250/1250 [==============================] - 140s 112ms/step - loss: 0.7351 - accuracy: 0.7460 - val_loss: 0.7926 - val_accuracy: 0.7313
# Epoch 16/50
# 1250/1250 [==============================] - 143s 114ms/step - loss: 0.7205 - accuracy: 0.7488 - val_loss: 0.8047 - val_accuracy: 0.7280
# Epoch 17/50
# 1250/1250 [==============================] - 137s 109ms/step - loss: 0.7123 - accuracy: 0.7517 - val_loss: 0.8024 - val_accuracy: 0.7323
# Epoch 18/50
# 1250/1250 [==============================] - 145s 116ms/step - loss: 0.6995 - accuracy: 0.7578 - val_loss: 0.8194 - val_accuracy: 0.7170
# Epoch 19/50
# 1250/1250 [==============================] - 133s 107ms/step - loss: 0.6886 - accuracy: 0.7615 - val_loss: 0.8108 - val_accuracy: 0.7235
# Epoch 20/50
# 1250/1250 [==============================] - 120s 96ms/step - loss: 0.6897 - accuracy: 0.7600 - val_loss: 0.7673 - val_accuracy: 0.7361
# Epoch 21/50
# 1250/1250 [==============================] - 122s 97ms/step - loss: 0.6775 - accuracy: 0.7646 - val_loss: 0.7937 - val_accuracy: 0.7296
# Epoch 22/50
# 1250/1250 [==============================] - 124s 99ms/step - loss: 0.6696 - accuracy: 0.7669 - val_loss: 0.7879 - val_accuracy: 0.7328
# Epoch 23/50
# 1250/1250 [==============================] - 124s 99ms/step - loss: 0.6681 - accuracy: 0.7672 - val_loss: 0.7796 - val_accuracy: 0.7350
# Epoch 24/50
# 1250/1250 [==============================] - 121s 97ms/step - loss: 0.6656 - accuracy: 0.7683 - val_loss: 0.8294 - val_accuracy: 0.7159
# Epoch 25/50
# 1250/1250 [==============================] - 125s 100ms/step - loss: 0.6540 - accuracy: 0.7731 - val_loss: 0.7848 - val_accuracy: 0.7361
# Epoch 26/50
# 1250/1250 [==============================] - 121s 97ms/step - loss: 0.6513 - accuracy: 0.7720 - val_loss: 0.7945 - val_accuracy: 0.7324
# Epoch 27/50
# 1250/1250 [==============================] - 134s 107ms/step - loss: 0.6513 - accuracy: 0.7739 - val_loss: 0.7862 - val_accuracy: 0.7315
# Epoch 28/50
# 1250/1250 [==============================] - 120s 96ms/step - loss: 0.6451 - accuracy: 0.7738 - val_loss: 0.7725 - val_accuracy: 0.7367
# Epoch 29/50
# 1250/1250 [==============================] - 119s 95ms/step - loss: 0.6397 - accuracy: 0.7754 - val_loss: 0.7644 - val_accuracy: 0.7418
# Epoch 30/50
# 1250/1250 [==============================] - 136s 109ms/step - loss: 0.6416 - accuracy: 0.7760 - val_loss: 0.7755 - val_accuracy: 0.7325
# Epoch 31/50
# 1250/1250 [==============================] - 146s 117ms/step - loss: 0.6315 - accuracy: 0.7814 - val_loss: 0.7671 - val_accuracy: 0.7377
# Epoch 32/50
# 1250/1250 [==============================] - 127s 102ms/step - loss: 0.6339 - accuracy: 0.7785 - val_loss: 0.8429 - val_accuracy: 0.7153
# Epoch 33/50
# 1250/1250 [==============================] - 131s 105ms/step - loss: 0.6244 - accuracy: 0.7825 - val_loss: 0.7994 - val_accuracy: 0.7312
# Epoch 34/50
# 1250/1250 [==============================] - 137s 110ms/step - loss: 0.6200 - accuracy: 0.7855 - val_loss: 0.7739 - val_accuracy: 0.7382
# Epoch 35/50
# 1250/1250 [==============================] - 117s 93ms/step - loss: 0.6225 - accuracy: 0.7847 - val_loss: 0.7793 - val_accuracy: 0.7301
# Epoch 36/50
# 1250/1250 [==============================] - 155s 124ms/step - loss: 0.6137 - accuracy: 0.7829 - val_loss: 0.7747 - val_accuracy: 0.7355
# Epoch 37/50
# 1250/1250 [==============================] - 158s 126ms/step - loss: 0.6119 - accuracy: 0.7850 - val_loss: 0.7535 - val_accuracy: 0.7455
# Epoch 38/50
# 1250/1250 [==============================] - 121s 96ms/step - loss: 0.6074 - accuracy: 0.7908 - val_loss: 0.7675 - val_accuracy: 0.7419
# Epoch 39/50
# 1250/1250 [==============================] - 113s 90ms/step - loss: 0.6052 - accuracy: 0.7897 - val_loss: 0.7843 - val_accuracy: 0.7331
# Epoch 40/50
# 1250/1250 [==============================] - 111s 89ms/step - loss: 0.6029 - accuracy: 0.7897 - val_loss: 0.7595 - val_accuracy: 0.7455
# Epoch 41/50
# 1250/1250 [==============================] - 131s 104ms/step - loss: 0.6017 - accuracy: 0.7899 - val_loss: 0.7793 - val_accuracy: 0.7384
# Epoch 42/50
# 1250/1250 [==============================] - 110s 88ms/step - loss: 0.5964 - accuracy: 0.7903 - val_loss: 0.7638 - val_accuracy: 0.7411
# Epoch 43/50
# 1250/1250 [==============================] - 111s 88ms/step - loss: 0.5988 - accuracy: 0.7889 - val_loss: 0.7590 - val_accuracy: 0.7460
# Epoch 44/50
# 1250/1250 [==============================] - 111s 89ms/step - loss: 0.5988 - accuracy: 0.7893 - val_loss: 0.7954 - val_accuracy: 0.7323
# Epoch 45/50
# 1250/1250 [==============================] - 118s 95ms/step - loss: 0.5899 - accuracy: 0.7948 - val_loss: 0.7777 - val_accuracy: 0.7410
# Epoch 46/50
# 1250/1250 [==============================] - 129s 103ms/step - loss: 0.5920 - accuracy: 0.7928 - val_loss: 0.7631 - val_accuracy: 0.7448
# Epoch 47/50
# 1250/1250 [==============================] - 112s 90ms/step - loss: 0.5926 - accuracy: 0.7932 - val_loss: 0.7461 - val_accuracy: 0.7497
# Epoch 48/50
# 1250/1250 [==============================] - 140s 112ms/step - loss: 0.5875 - accuracy: 0.7952 - val_loss: 0.7970 - val_accuracy: 0.7251
# Epoch 49/50
# 1250/1250 [==============================] - 149s 120ms/step - loss: 0.5809 - accuracy: 0.7965 - val_loss: 0.7688 - val_accuracy: 0.7385
# Epoch 50/50
# 1250/1250 [==============================] - 127s 102ms/step - loss: 0.5794 - accuracy: 0.7964 - val_loss: 0.7528 - val_accuracy: 0.7486

# %%
score = model.evaluate(X_test, y_test_c, batch_size=128, verbose=0)

for i in range(len(score)):
    print("Test " + model.metrics_names[i] + " = %.3f" % score[i])
# Out:
# Test loss = 0.758
# Test accuracy = 0.747

# %%
PlotModelEval(model, history, X_test, y_test, cifar_labels)

# %% [markdown]
# #### **<span style="color:red">Question 8:</span>**
# Train the model and save the evaluation image for the report.

# %% [markdown]
# #### **<span style="color:red">Question 9:</span>**
# When using BatchNorm one must take care to select a good minibatch size. Describe what problems might arise if the wrong minibatch size is used.
#
# You can reason about this given the description of BatchNorm above, or you can search for the information in other sources. Do not forget to provide links to the sources if you do!

# %% [markdown]
# ### **5. Putting it all together**
# We now want you to create your own model based on what you have learned. We want you to experiment and see what works and what doesn't, so don't go crazy with the number of epochs until you think you have something that works.
#
# To pass this assignment, we want you to acheive **75%** accuracy on the test data in no more than **25 epochs**. This is possible using the layers and techniques we have explored in this notebook, but you are free to use any other methods that we didn't cover. (You are obviously not allowed to cheat, for example by training on the test data.)

# %%
from tensorflow.keras.utils import plot_model
from tensorflow.keras.layers import ReLU, GlobalAveragePooling2D
x_in = Input(shape=X_train.shape[1:])

# === Add your code here ===
x = Conv2D(64, 7,padding ='same')(x_in)
x = BatchNormalization(momentum =0.75)(x)
x = MaxPooling2D(pool_size=(3, 3))(x)
y = x
x = Conv2D(64, 3,padding ='same')(x)
x = BatchNormalization(momentum =0.75)(x)
x = ReLU()(x)
x= Conv2D(64, 3,padding ='same')(x)
x = BatchNormalization(momentum =0.75)(x)
x=x+y
x = ReLU()(x)
y = x
x = Conv2D(64, 3,padding ='same')(x)
x = BatchNormalization(momentum =0.75)(x)
x = ReLU()(x)
x = Conv2D(64, 3,padding ='same')(x)
x = BatchNormalization(momentum =0.75)(x)
x=x+y
x = ReLU()(x)
y = x
y = Conv2D(1, 1,padding ='same')(y)
x = Conv2D(64, 3,padding ='same')(x)
x = BatchNormalization(momentum =0.75)(x)
x = ReLU()(x)
x = Conv2D(64, 3,padding ='same')(x)
x = BatchNormalization(momentum =0.75)(x)
x=x+y
x = ReLU()(x)
y = x
x = Conv2D(64, 3,padding ='same')(x)
x = BatchNormalization(momentum =0.75)(x)
x = ReLU()(x)
x= Conv2D(64, 3,padding ='same')(x)
x = BatchNormalization(momentum =0.75)(x)
x=x+y
x = ReLU()(x)
x = GlobalAveragePooling2D()(x)
x = Flatten()(x)
x = Dense(10, activation='softmax')(x)
# ==========================

model = Model(inputs=x_in, outputs=x)

sgd = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(loss='categorical_crossentropy', metrics=['accuracy'], optimizer=sgd)
model.summary(100)
plot_model(model, show_shapes=True, show_layer_names=False)
# Out:
# Model: "functional_9"
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# input_8 (InputLayer)             [(None, 32, 32, 3)]   0
# ____________________________________________________________________________________________________
# conv2d_8 (Conv2D)                (None, 32, 32, 64)    9472        input_8[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_4 (BatchNorm (None, 32, 32, 64)    256         conv2d_8[0][0]
# ____________________________________________________________________________________________________
# max_pooling2d_7 (MaxPooling2D)   (None, 10, 10, 64)    0           batch_normalization_4[0][0]
# ____________________________________________________________________________________________________
# conv2d_9 (Conv2D)                (None, 10, 10, 64)    36928       max_pooling2d_7[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_5 (BatchNorm (None, 10, 10, 64)    256         conv2d_9[0][0]
# ____________________________________________________________________________________________________
# re_lu (ReLU)                     (None, 10, 10, 64)    0           batch_normalization_5[0][0]
# ____________________________________________________________________________________________________
# conv2d_10 (Conv2D)               (None, 10, 10, 64)    36928       re_lu[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_6 (BatchNorm (None, 10, 10, 64)    256         conv2d_10[0][0]
# ____________________________________________________________________________________________________
# tf_op_layer_AddV2 (TensorFlowOpL [(None, 10, 10, 64)]  0           batch_normalization_6[0][0]
#                                                                    max_pooling2d_7[0][0]
# ____________________________________________________________________________________________________
# re_lu_1 (ReLU)                   (None, 10, 10, 64)    0           tf_op_layer_AddV2[0][0]
# ____________________________________________________________________________________________________
# conv2d_11 (Conv2D)               (None, 10, 10, 64)    36928       re_lu_1[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_7 (BatchNorm (None, 10, 10, 64)    256         conv2d_11[0][0]
# ____________________________________________________________________________________________________
# re_lu_2 (ReLU)                   (None, 10, 10, 64)    0           batch_normalization_7[0][0]
# ____________________________________________________________________________________________________
# conv2d_12 (Conv2D)               (None, 10, 10, 64)    36928       re_lu_2[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_8 (BatchNorm (None, 10, 10, 64)    256         conv2d_12[0][0]
# ____________________________________________________________________________________________________
# tf_op_layer_AddV2_1 (TensorFlowO [(None, 10, 10, 64)]  0           batch_normalization_8[0][0]
#                                                                    re_lu_1[0][0]
# ____________________________________________________________________________________________________
# re_lu_3 (ReLU)                   (None, 10, 10, 64)    0           tf_op_layer_AddV2_1[0][0]
# ____________________________________________________________________________________________________
# conv2d_14 (Conv2D)               (None, 10, 10, 64)    36928       re_lu_3[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_9 (BatchNorm (None, 10, 10, 64)    256         conv2d_14[0][0]
# ____________________________________________________________________________________________________
# re_lu_4 (ReLU)                   (None, 10, 10, 64)    0           batch_normalization_9[0][0]
# ____________________________________________________________________________________________________
# conv2d_15 (Conv2D)               (None, 10, 10, 64)    36928       re_lu_4[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_10 (BatchNor (None, 10, 10, 64)    256         conv2d_15[0][0]
# ____________________________________________________________________________________________________
# conv2d_13 (Conv2D)               (None, 10, 10, 1)     65          re_lu_3[0][0]
# ____________________________________________________________________________________________________
# tf_op_layer_AddV2_2 (TensorFlowO [(None, 10, 10, 64)]  0           batch_normalization_10[0][0]
#                                                                    conv2d_13[0][0]
# ____________________________________________________________________________________________________
# re_lu_5 (ReLU)                   (None, 10, 10, 64)    0           tf_op_layer_AddV2_2[0][0]
# ____________________________________________________________________________________________________
# conv2d_16 (Conv2D)               (None, 10, 10, 64)    36928       re_lu_5[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_11 (BatchNor (None, 10, 10, 64)    256         conv2d_16[0][0]
# ____________________________________________________________________________________________________
# re_lu_6 (ReLU)                   (None, 10, 10, 64)    0           batch_normalization_11[0][0]
# ____________________________________________________________________________________________________
# conv2d_17 (Conv2D)               (None, 10, 10, 64)    36928       re_lu_6[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_12 (BatchNor (None, 10, 10, 64)    256         conv2d_17[0][0]
# ____________________________________________________________________________________________________
# tf_op_layer_AddV2_3 (TensorFlowO [(None, 10, 10, 64)]  0           batch_normalization_12[0][0]
#                                                                    re_lu_5[0][0]
# ____________________________________________________________________________________________________
# re_lu_7 (ReLU)                   (None, 10, 10, 64)    0           tf_op_layer_AddV2_3[0][0]
# ____________________________________________________________________________________________________
# global_average_pooling2d (Global (None, 64)            0           re_lu_7[0][0]
# ____________________________________________________________________________________________________
# flatten_4 (Flatten)              (None, 64)            0           global_average_pooling2d[0][0]
# ____________________________________________________________________________________________________
# dense_6 (Dense)                  (None, 10)            650         flatten_4[0][0]
# ====================================================================================================
# Total params: 307,915
# Trainable params: 306,763
# Non-trainable params: 1,152
# ____________________________________________________________________________________________________

# %%
history = model.fit(X_train, y_train_c, batch_size=32, epochs=25, verbose=1, validation_split=0.2)
# Out:
# Epoch 1/25
# 1250/1250 [==============================] - 419s 336ms/step - loss: 1.4391 - accuracy: 0.4745 - val_loss: 1.5568 - val_accuracy: 0.5010
# Epoch 2/25
# 1250/1250 [==============================] - 429s 343ms/step - loss: 1.0586 - accuracy: 0.6226 - val_loss: 0.9410 - val_accuracy: 0.6641
# Epoch 3/25
# 1250/1250 [==============================] - 431s 345ms/step - loss: 0.8765 - accuracy: 0.6930 - val_loss: 0.9194 - val_accuracy: 0.6776
# Epoch 4/25
# 1250/1250 [==============================] - 406s 325ms/step - loss: 0.7520 - accuracy: 0.7408 - val_loss: 0.7281 - val_accuracy: 0.7422
# Epoch 5/25
# 1250/1250 [==============================] - 329s 263ms/step - loss: 0.6577 - accuracy: 0.7704 - val_loss: 0.7287 - val_accuracy: 0.7497
# Epoch 6/25
# 1250/1250 [==============================] - 331s 265ms/step - loss: 0.5890 - accuracy: 0.7959 - val_loss: 0.6882 - val_accuracy: 0.7622
# Epoch 7/25
# 1250/1250 [==============================] - 327s 262ms/step - loss: 0.5334 - accuracy: 0.8134 - val_loss: 0.6434 - val_accuracy: 0.7764
# Epoch 8/25
# 1250/1250 [==============================] - 333s 266ms/step - loss: 0.4849 - accuracy: 0.8327 - val_loss: 0.6305 - val_accuracy: 0.7846
# Epoch 9/25
# 1250/1250 [==============================] - 331s 265ms/step - loss: 0.4402 - accuracy: 0.8478 - val_loss: 0.6410 - val_accuracy: 0.7869
# Epoch 10/25
# 1250/1250 [==============================] - 332s 266ms/step - loss: 0.3941 - accuracy: 0.8626 - val_loss: 0.6692 - val_accuracy: 0.7837
# Epoch 11/25
# 1250/1250 [==============================] - 330s 264ms/step - loss: 0.3585 - accuracy: 0.8763 - val_loss: 0.6447 - val_accuracy: 0.7907
# Epoch 12/25
# 1250/1250 [==============================] - 331s 265ms/step - loss: 0.3262 - accuracy: 0.8866 - val_loss: 0.6570 - val_accuracy: 0.7920
# Epoch 13/25
# 1250/1250 [==============================] - 332s 265ms/step - loss: 0.2909 - accuracy: 0.8983 - val_loss: 0.6751 - val_accuracy: 0.7879
# Epoch 14/25
# 1250/1250 [==============================] - 332s 265ms/step - loss: 0.2667 - accuracy: 0.9070 - val_loss: 0.6845 - val_accuracy: 0.7956
# Epoch 15/25
# 1250/1250 [==============================] - 332s 265ms/step - loss: 0.2374 - accuracy: 0.9171 - val_loss: 0.6530 - val_accuracy: 0.8125
# Epoch 16/25
# 1250/1250 [==============================] - 329s 263ms/step - loss: 0.2183 - accuracy: 0.9233 - val_loss: 0.7553 - val_accuracy: 0.7888
# Epoch 17/25
# 1250/1250 [==============================] - 326s 261ms/step - loss: 0.2000 - accuracy: 0.9300 - val_loss: 0.7584 - val_accuracy: 0.7970
# Epoch 18/25
# 1250/1250 [==============================] - 355s 284ms/step - loss: 0.1754 - accuracy: 0.9399 - val_loss: 0.7579 - val_accuracy: 0.7833
# Epoch 19/25
# 1250/1250 [==============================] - 336s 269ms/step - loss: 0.1589 - accuracy: 0.9419 - val_loss: 0.7636 - val_accuracy: 0.8010
# Epoch 20/25
# 1250/1250 [==============================] - 333s 267ms/step - loss: 0.1481 - accuracy: 0.9482 - val_loss: 0.8002 - val_accuracy: 0.7927
# Epoch 21/25
# 1250/1250 [==============================] - 333s 266ms/step - loss: 0.1382 - accuracy: 0.9517 - val_loss: 0.7999 - val_accuracy: 0.7958
# Epoch 22/25
# 1250/1250 [==============================] - 331s 265ms/step - loss: 0.1181 - accuracy: 0.9584 - val_loss: 0.8456 - val_accuracy: 0.7937
# Epoch 23/25
# 1250/1250 [==============================] - 315s 252ms/step - loss: 0.1137 - accuracy: 0.9611 - val_loss: 0.8033 - val_accuracy: 0.8023
# Epoch 24/25
# 1250/1250 [==============================] - 315s 252ms/step - loss: 0.0932 - accuracy: 0.9675 - val_loss: 0.8553 - val_accuracy: 0.8036
# Epoch 25/25
# 1250/1250 [==============================] - 322s 258ms/step - loss: 0.0901 - accuracy: 0.9674 - val_loss: 0.8551 - val_accuracy: 0.8098

# %%
score = model.evaluate(X_test, y_test_c, batch_size=128, verbose=0)

for i in range(len(score)):
    print("Test " + model.metrics_names[i] + " = %.3f" % score[i])
# Out:
# Test loss = 0.875
# Test accuracy = 0.797

# %%
PlotModelEval(model, history, X_test, y_test, cifar_labels)

# %% [markdown]
# #### **<span style="color:red">Question 10:</span>**
# Design and train a model that achieves at least 75% test accuracy in at most 25 epochs. Save the evaluation image for the report. Also, in the report you should explain your model and motivate the design choices you have made.

# %% [markdown]
# ### **Want some extra challenge?**
# For those of you that feel the competitive spark right now, we will hold an **optional** competition where you can submit your trained model-file for evaluation. To make this fair, you are not allowed to train for more than **50 epochs**, but other than that we want you to get creative. The competition is simple, we will evaluate all submitted models and the model with highest test accuracy wins. The prize is nothing less than eternal glory.
#
# Here are some things to look into, but note that we don't have the answers here. Any of these might improve the performance, or might not, or it might only work in combination with each other. This is up to you to figure out. This is how deep learning research often happens, trying things in a smart way to see what works best.
# * Tweak or change the optimizer or training parameters.
# * Tweak the filter parameters, such as numbers and sizes of filters.
# * Use other activation functions.
# * Add L1/L2 regularization (see https://www.tensorflow.org/api_docs/python/tf/keras/regularizers)
# * Include layers that we did not cover here (see https://www.tensorflow.org/api_docs/python/tf/keras/layers). For example, our best model uses the global pooling layers.
# * Take inspiration from some well-known architectures, such as ResNet or VGG16. (But don't just copy-paste those architectures. For one, what's the fun in that? Also, they take a long time to train, you will not have time.)
# * Use explicit model ensembing (training multiple models that vote on or average the outputs - this will also take a lot of time.)
# * Use data augmentation to create a larger training set (see https://www.tensorflow.org/api_docs/python/tf/keras/preprocessing/image/ImageDataGenerator).
#
# Write your competition model here. This way you can try different things without deleting the model you created above. Also set the GroupName variable to your LiU IDs or some unique name; that way our scripts can be a lot easier, thanks and good luck :)

# %%
GroupName = "Test"

x_in = Input(shape=X_train.shape[1:])

# Your code here

model = Model(inputs=x_in, outputs=x, name=GroupName)

# You can also change this if you want
sgd = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(loss='categorical_crossentropy', metrics=['accuracy'], optimizer=sgd)

# Print the summary and model image
model.summary(100)
plot_model(model, show_shapes=True, show_layer_names=False)

# %%
history = model.fit(X_train, y_train_c, batch_size=32, epochs=5, verbose=1, validation_split=0.2)

# %%
PlotModelEval(model, history, X_test, y_test, cifar_labels)

# %% [markdown]
# **Don't forget to save your model!**

# %%
model.save("CompetionModel_" + GroupName + ".h5")
